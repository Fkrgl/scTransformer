# %%
import scvelo
import numpy as np

# %% [markdown]
# scvelo has some standard datasets included, e.g. one about pancreatic endocrinogenesis. The package is for velocity analysis but in the inital stage we can use any scRNA-seq dataset.

# %%
anndata = scvelo.datasets.pancreatic_endocrinogenesis()
anndata
# Out:
# AnnData object with n_obs × n_vars = 3696 × 27998
#     obs: 'clusters_coarse', 'clusters', 'S_score', 'G2M_score'
#     var: 'highly_variable_genes'
#     uns: 'clusters_coarse_colors', 'clusters_colors', 'day_colors', 'neighbors', 'pca'
#     obsm: 'X_pca', 'X_umap'
#     layers: 'spliced', 'unspliced'
#     obsp: 'distances', 'connectivities'

# %%
anndata.var
# Out:
#         highly_variable_genes
# index
# Xkr4                    False
# Gm37381                   NaN
# Rp1                       NaN
# Rp1-1                     NaN
# Sox17                     NaN
# ...                       ...
# Gm28672                   NaN
# Gm28670                   NaN
# Gm29504                   NaN
# Gm20837                   NaN
# Erdr1                    True
#
# [27998 rows x 1 columns]

# %% [markdown]
# The spliced count `anndata.layers['spliced']` or later the transformed `anndata.X` (e.g. when we want to use the normalized and logarithmized data) is the one we're interested in.

# %%
# The spliced count of the first cell with 2356 non-zero genes out of 27998
anndata.layers['spliced'][0]
# Out:
# <1x27998 sparse matrix of type '<class 'numpy.float32'>'
# 	with 2356 stored elements in Compressed Sparse Row format>

# %% [markdown]
# As sensible preprocessing step we can filter out all genes which were counted less than 10 times with `filter_and_normalize`. This reduces the number of genes from 27998 down to 8357.

# %%
scvelo.pp.filter_and_normalize(anndata, min_shared_counts=10, n_top_genes=2400, flavor='cell_ranger', log=True)
# Out:
# Filtered out 19641 genes that are detected 10 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 2400 highly variable genes.
# Logarithmized X.

# %%
anndata.X.toarray().sum(axis=1)
# Out:
# array([619.51575, 519.5526 , 571.0186 , ..., 502.96722, 531.537  ,
#        633.9243 ], dtype=float32)

# %%
# The spliced count of the first cell with 2030 non-zero genes out of 8357
anndata.layers['spliced'][0]
# Out:
# <1x8357 sparse matrix of type '<class 'numpy.float32'>'
# 	with 2030 stored elements in Compressed Sparse Row format>

# %% [markdown]
# `scvelo` also directly calculates the highly variable genes:

# %%
highly_varaible_genes = []
for gene in anndata.var['highly_variable_genes'].index:
    if anndata.var['highly_variable_genes'][gene] == 'True':
        highly_varaible_genes.append(gene)

# %%
len(highly_varaible_genes)
highly_varaible_genes
# Out:
# ['Sntg1',
#  'Cops5',
#  'Sbspon',
#  'Pkhd1',
#  'Mcm3',
#  'Fam135a',
#  'Adgrb3',
#  'Zfp451',
#  'Tbc1d8',
#  'Fhl2',
#  'Slc40a1',
#  'Pms1',
#  'Pgap1',
#  'Ankrd44',
#  'Tyw5',
#  'Raph1',
#  'Klf7',
#  'Akr1cl',
#  'Ikzf2',
#  'Fn1',
#  'March4',
#  'Igfbp5',
#  'Tns1',
#  'Tmbim1',
#  'Fev',
#  'Cryba2',
#  'Tuba4a',
#  'Ptprn',
#  'Resp18',
#  'Epha4',
#  'Dock10',
#  'Sphkap',
#  'Dner',
#  'Hjurp',
#  'Hes6',
#  'Myeov2',
#  'Kif1a',
#  'Pam',
#  'Bcl2',
#  'Dbi',
#  'Tmem163',
#  'Mcm6',
#  'Nfasc',
#  'Atp2b4',
#  'Btg2',
#  'Adora1',
#  'Timm17a',
#  'Nav1',
#  'Trove2',
#  'Rgs2',
#  'Swt1',
#  'Rgl1',
#  'Lamc1',
#  'Npl',
#  'Xpr1',
#  'Qsox1',
#  'Fam163a',
#  'Soat1',
#  'Pappa2',
#  'Dars2',
#  'Fmo1',
#  'Fmo2',
#  'BC055324',
#  'Atp1b1',
#  'Mpzl1',
#  'Pea15a',
#  'Cep170',
#  'Akt3',
#  'Enah',
#  'Capn2',
#  'Tgfb2',
#  'Cenpf',
#  'Prox1',
#  'Atf3',
#  'Dtl',
#  'St18',
#  'Cspp1',
#  'Sulf1',
#  'Kcnb2',
#  'Gdap1',
#  'Gsta3',
#  'Col9a1',
#  'Khdrbs2',
#  'Dst',
#  'Ptpn18',
#  'Hs6st1',
#  'Cox5b',
#  'Inpp4a',
#  'Il1r1',
#  'Wdr75',
#  'Coq10b',
#  'Plcl1',
#  'Zdbf2',
#  'Adam23',
#  'Map2',
#  'Unc80',
#  'Igfbp2',
#  'Vil1',
#  'Bcs1l',
#  'Dnajb2',
#  'Itm2c',
#  'Ramp1',
#  'Rnpepl1',
#  'Ppp1r7',
#  'Sept2',
#  'Bok',
#  'Fam174a',
#  '2310035C23Rik',
#  '3110009E18Rik',
#  'Eif2d',
#  'Nucks1',
#  'Lrrn2',
#  'Plekha6',
#  'Kdm5b',
#  'Arl8a',
#  'Kif14',
#  'Glrx2',
#  'Uchl5',
#  'Apobec4',
#  'Rgs16',
#  'Glul',
#  'Rxrg',
#  'Igsf8',
#  'Igsf9',
#  'Tagln2',
#  'Sdccag8',
#  'Zbtb18',
#  'Cdc42bpa',
#  'Dusp10',
#  'Prox1os',
#  'Tmem206',
#  'Syne1',
#  'Fbxo5',
#  'Rgs17',
#  'Samd5',
#  'Aig1',
#  'Adgrg6',
#  'Arg1',
#  'Tmem200a',
#  'Trmt11',
#  'Ncoa7',
#  'Marcks',
#  'Slc16a10',
#  'Fig4',
#  'Foxo3',
#  'Serinc1',
#  'Sept10',
#  'H2afy2',
#  '2010107G23Rik',
#  'Supv3l1',
#  'Stox1',
#  'Lrrtm3',
#  'Cdk1',
#  'Phyhipl',
#  'Bicc1',
#  'Gstt1',
#  'Gstt2',
#  'Prmt2',
#  'Col18a1',
#  'Gm10941',
#  '2610008E11Rik',
#  'Shc2',
#  'Abhd17a',
#  'Nfic',
#  'Tle6',
#  'Rtcb',
#  'Parpbp',
#  'Utp20',
#  'Slc25a3',
#  'Nedd1',
#  'Gm15915',
#  'Glipr1',
#  'Nup107',
#  'Rap1b',
#  'Hmga2',
#  'Dtx3',
#  'Ikzf4',
#  'Ppp1r14c',
#  'Akap12',
#  'Lrp11',
#  'Plagl1',
#  'Ahi1',
#  'Stx7',
#  'Soga3',
#  'Sesn1',
#  'Cd24a',
#  'Prep',
#  'Sim1',
#  'Rfx6',
#  'Gja1',
#  'Hsf2',
#  'Pkib',
#  'Smpdl3a',
#  'Spock2',
#  'Neurog3',
#  'Pbld2',
#  'Dnajc12',
#  'Gnaz',
#  'Rab36',
#  'Upb1',
#  'S100b',
#  'Tspear',
#  '1810043G02Rik',
#  'Palm',
#  'Cnn2',
#  'Atp5d',
#  'Cirbp',
#  'Oaz1',
#  'Gadd45b',
#  'Zfr2',
#  'Cactin',
#  'Aes',
#  'Tle2',
#  '1500009L16Rik',
#  'Tcp11l2',
#  'Timp3',
#  '1810014B01Rik',
#  'Igf1',
#  'Arl1',
#  'Fgd6',
#  'Tmcc3',
#  'Csrp2',
#  'Phlda1',
#  'Tspan8',
#  'Cpm',
#  'Mdm1',
#  'Gns',
#  'Ppm1h',
#  'Atp5b',
#  'Pan2',
#  'Tcn2',
#  'Znrf3',
#  'Gck',
#  'Camk2b',
#  'Tbrg4',
#  'Ddc',
#  'Grb10',
#  'Meis1',
#  'Actr2',
#  'Ehbp1',
#  'Vrk2',
#  'Chac2',
#  'Hmmr',
#  'Ccng1',
#  'Cyfip2',
#  'Sqstm1',
#  'Anxa6',
#  'Sparc',
#  'Gemin5',
#  'Fam183b',
#  'Cox10',
#  'Dnah9',
#  'Pfas',
#  'Chd3',
#  'Kdm6b',
#  'Wrap53',
#  'Eif4a1',
#  'Eif5a',
#  'Pfn1',
#  'Smtnl2',
#  'Rap1gap2',
#  'Serpinf1',
#  'Rph3al',
#  'Abr',
#  'Trp53i13',
#  'Tmem97',
#  'Nlk',
#  'Lgals9',
#  'Asic2',
#  'Ccl9',
#  'Tada2a',
#  'Brip1',
#  'Ypel2',
#  'Gdpd1',
#  'Msi2',
#  'Scpep1',
#  'Luc7l3',
#  'Abcc3',
#  'Eme1',
#  'Pdk2',
#  'Igf2bp1',
#  'Gpr179',
#  'Fbxl20',
#  'Neurod2',
#  'Top2a',
#  'Krt19',
#  'Krt17',
#  'Hap1',
#  'Acly',
#  'Stat3',
#  'Etv4',
#  'Dusp3',
#  'Ppy',
#  'Pyy',
#  'Hdac5',
#  'Dcakd',
#  '1700023F06Rik',
#  'Arhgap27',
#  'Smarcd2',
#  'Kpna2',
#  'Nol11',
#  'Pitpnc1',
#  'Cacng4',
#  'Prkca',
#  'Wipi1',
#  '2610035D17Rik',
#  'Btbd17',
#  'Grin2c',
#  'Hid1',
#  'Atp5h',
#  'Sumo2',
#  'Trim47',
#  'Acox1',
#  'St6galnac2',
#  'Mxra7',
#  'Tk1',
#  'Rbfox3',
#  'Tbc1d16',
#  'Fam195b',
#  'P4hb',
#  'Notum',
#  'Selm',
#  'Gal3st1',
#  'Xbp1',
#  'Upp1',
#  'C1d',
#  'Peli1',
#  'Pnpt1',
#  'Ccdc88a',
#  'Cpeb4',
#  'Ebf1',
#  'Rnf130',
#  'Gm26542',
#  'Nhp2',
#  'Kif3a',
#  'Hint1',
#  'Gpx3',
#  'Slc36a1',
#  'Wnt9a',
#  'Drg2',
#  'Alkbh5',
#  'Dhrs7b',
#  'Map2k3',
#  'Gas7',
#  'Gsg1l2',
#  'Aurkb',
#  'Vamp2',
#  'Plscr3',
#  'Dlg4',
#  'Psmb6',
#  'Zzef1',
#  'Atp2a3',
#  'Rtn4rl1',
#  'Slc43a2',
#  'Ywhae',
#  'Timm22',
#  'Fam222b',
#  'Spag5',
#  'Rhbdl3',
#  'Zfp207',
#  'Ccl4',
#  'Synrg',
#  'Lhx1os',
#  'Cuedc1',
#  'Spag9',
#  'Tob1',
#  'Samd14',
#  'Slc35b1',
#  'Gip',
#  'Skap1',
#  'Gast',
#  'Nkiras2',
#  'Wnk4',
#  'Rpl27',
#  'Ifi35',
#  'BC030867',
#  'Mapt',
#  'Prkar1a',
#  'Sox9',
#  'Cog1',
#  'Ttyh2',
#  'Kif19a',
#  'Rab37',
#  'Slc16a5',
#  'Sept9',
#  'Birc5',
#  'Baiap2',
#  'Dtnbos',
#  'Ywhaq',
#  '2410018L13Rik',
#  'Id2',
#  'Dus4l',
#  'Hbp1',
#  'Tspan13',
#  'Bzw2',
#  'Scin',
#  'Dnajb9',
#  'Nfkbia',
#  'Mis18bp1',
#  'Pole2',
#  'Pygl',
#  'Trim9',
#  'Rtn1',
#  'Dhrs7',
#  'Gpx2',
#  'Rab15',
#  'Zfp36l1',
#  'Erh',
#  'Tmed8',
#  'Cep128',
#  'Sel1l',
#  'Eml5',
#  'Efcab11',
#  'Lgmn',
#  'Serpina10',
#  'Serpina6',
#  'Serpina1b',
#  'Serpina1c',
#  'Serpina1e',
#  'Clmn',
#  'Ckb',
#  'Dnmt3a',
#  'Nol10',
#  'Hpcal1',
#  'Iah1',
#  'Taf1b',
#  'Rrm2',
#  'Kidins220',
#  'Tssc1',
#  'Myt1l',
#  'Lamb1',
#  'Efcab10',
#  'Dgkb',
#  'Etv1',
#  'Nubpl',
#  'Daam1',
#  '1700086L19Rik',
#  'Eif2s1',
#  'Smoc1',
#  'Acot1',
#  'Coq6',
#  'Fos',
#  'Gstz1',
#  'Flrt2',
#  'Ttc8',
#  'Tdp1',
#  'Chga',
#  'Evl',
#  'Dlk1',
#  'Meg3',
#  'Mirg',
#  'Trmt61a',
#  'Siva1',
#  'Crip1',
#  '4930427A07Rik',
#  'Ptprn2',
#  'Akr1c12',
#  'Rala',
#  'Pou6f2',
#  'Zscan26',
#  'Scgn',
#  'Gmnn',
#  'Serpinb1a',
#  'Ssr1',
#  'Atxn1',
#  'Dek',
#  'Card19',
#  'Cenpp',
#  'Diras2',
#  'Cltb',
#  'Dbn1',
#  'Pdlim7',
#  'Spock1',
#  'Hnrnpk',
#  'Slc28a3',
#  'Ptch1',
#  'Cdc14b',
#  'Ctsl',
#  'Uqcrb',
#  'Adamts16',
#  'Irx1',
#  'Pdcd6',
#  'Sdha',
#  'Cox7c',
#  'Bhmt2',
#  'Scamp1',
#  'Pde8b',
#  'Sv2c',
#  'Hmgcr',
#  'Btf3',
#  'Tmem171',
#  'Map1b',
#  'Mrps36',
#  'Ccnb1',
#  'Pik3r1',
#  'Mast4',
#  'Nln',
#  'Fam159b',
#  'Rab3c',
#  'Skiv2l2',
#  'Gpx8',
#  'Isl1',
#  'Akr1c13',
#  'Akr1c19',
#  'Klf6',
#  'Heatr1',
#  'Ero1lb',
#  'Gng4',
#  'Elmo1',
#  'Hist1h2bc',
#  'Dcdc2a',
#  'Phactr1',
#  'Jarid2',
#  'Gmpr',
#  'Cks2',
#  'Cplx2',
#  'Tspan17',
#  'Irx2',
#  'Slc12a7',
#  'Pcsk1',
#  'Ell2',
#  'Glrx',
#  'Dhfr',
#  'Tbca',
#  'Enc1',
#  'Mrps27',
#  'Plk2',
#  'Emb',
#  'Paip1',
#  'Hmgcs1',
#  '4930452B06Rik',
#  'Cadps',
#  'Rpl15',
#  'Ube2e1',
#  'Gng2',
#  'Mrps16',
#  'Kcnma1',
#  'Nisch',
#  'Timm23',
#  'Cdhr1',
#  'Gch1',
#  '1700011H14Rik',
#  'Osgep',
#  'Supt16',
#  'Slc7a8',
#  'Zfhx2',
#  'Jph4',
#  'Psme2',
#  'Ska3',
#  'Ptk2b',
#  'Dpysl2',
#  'Cdca2',
#  'Bmp1',
#  'Fndc3a',
#  'Pcdh9',
#  'Dach1',
#  'Dis3',
#  'Mycbp2',
#  'Synpr',
#  'Nkiras1',
#  'Zswim8',
#  'Tmem110',
#  'Sema3g',
#  'Glud1',
#  'Gm8113',
#  'Cdkn3',
#  'Parp2',
#  'Rnase4',
#  'Slc39a2',
#  'Arhgef40',
#  'Rpgrip1',
#  'Mmp14',
#  'Irf9',
#  'Rec8',
#  'Nfatc4',
#  'Fgf9',
#  'Mipep',
#  'Ctsb',
#  'Pinx1',
#  'Pbk',
#  'Clu',
#  'Trim35',
#  'Lgi3',
#  'Epsti1',
#  'Cldn10',
#  'Dnajc3',
#  'Hs6st3',
#  'Mbnl2',
#  'Ghr',
#  'Sub1',
#  'Basp1',
#  'Fam105a',
#  'Snhg18',
#  'Rpl30',
#  'Cox6c',
#  'Rnf19a',
#  'Ncald',
#  'Rrm2b',
#  'Klf10',
#  'Nudcd1',
#  'Eif3h',
#  'Enpp2',
#  '9130401M01Rik',
#  'Atad2',
#  'Fbxo32',
#  'Mtss1',
#  'Asap1',
#  'Ndrg1',
#  'Ly6h',
#  'Puf60',
#  'Rbfox2',
#  'Mfng',
#  'Ankrd54',
#  '1700088E04Rik',
#  'Tmem184b',
#  'Csnk1e',
#  'Sun2',
#  'Chadl',
#  'Desi1',
#  'Cenpm',
#  'Arfgap3',
#  'Scube1',
#  '1810041L15Rik',
#  'Wnt7b',
#  'Cpne8',
#  '2610037D02Rik',
#  'Vdr',
#  'Col2a1',
#  'Fkbp11',
#  'Tuba1a',
#  'Mcrs1',
#  'Racgap1',
#  'Aaas',
#  'Atp5g2',
#  'Calcoco1',
#  'Ppp1r1a',
#  'Sepp1',
#  'Plcxd3',
#  'Lifr',
#  'Gdnf',
#  'Capsl',
#  'Fam134b',
#  'March11',
#  'Ank',
#  'Dap',
#  'Cpq',
#  'Spag1',
#  'Aard',
#  'Slc30a8',
#  'Med30',
#  'Deptor',
#  'Mtbp',
#  'Tbc1d31',
#  'Trib1',
#  'Khdrbs3',
#  'Mapk15',
#  'Gcat',
#  'Apobec3',
#  'Rbx1',
#  'Sept3',
#  'Creld2',
#  'Ncaph2',
#  'Mapk8ip2',
#  'Cntn1',
#  'Pdzrn4',
#  '4930578M01Rik',
#  'Tuba1c',
#  'Troap',
#  'Gpd1',
#  'Grasp',
#  'Nr4a1',
#  'Krt7',
#  'Krt18',
#  'Espl1',
#  'Pcbp2',
#  'Copz1',
#  'Srl',
#  'Ubald1',
#  'Emp2',
#  'Litaf',
#  'Marf1',
#  'Fgd4',
#  'Sdf2l1',
#  'Abcc5',
#  '2510009E07Rik',
#  'Sst',
#  'Fgf12',
#  'Stxbp5l',
#  'Timmdc1',
#  'Gap43',
#  'Cd200',
#  'Gm609',
#  'Phldb2',
#  'Pvrl3',
#  'Bbx',
#  'Alcam',
#  'Cmss1',
#  'St3gal6',
#  'Epha3',
#  'Cadm2',
#  'Robo2',
#  'Nrip1',
#  'Btg3',
#  'Atp5j',
#  'App',
#  'Adamts1',
#  'Hmgn1',
#  'Zfp174',
#  'Mkl2',
#  'Mpv17l',
#  'Efcab1',
#  'Mapk1',
#  'Ypel1',
#  'Arvcf',
#  'Gnb1l',
#  'Klhl24',
#  'Vwa5b2',
#  'Psmd2',
#  'Fam131a',
#  'Lpp',
#  'Hes1',
#  'Muc4',
#  'Heg1',
#  'Itgb5',
#  'Ildr1',
#  'Polq',
#  'Fstl1',
#  'Gsk3b',
#  'Igsf11',
#  'Zbtb20',
#  'Mina',
#  'Dopey2',
#  'Ripply3',
#  'Ttc3',
#  'Bace2',
#  'Dynlt1a',
#  'Pacrg',
#  'Igf2r',
#  'Wtap',
#  'Dll1',
#  'Psmb1',
#  'Zfp213',
#  'Tnfrsf12a',
#  'Tceb2',
#  'Gnptg',
#  'Baiap3',
#  'Cacna1h',
#  'Chtf18',
#  'Cuta',
#  'Spdef',
#  'Tcp11',
#  'Clps',
#  'Trp53cor1',
#  'Mtch1',
#  'Tff3',
#  'Wdr4',
#  'Cbs',
#  'Akap8l',
#  'Gm19412',
#  'H2-K1',
#  'Csnk2b',
#  'Ddr1',
#  'Atat1',
#  'Slc29a1',
#  'Rsph9',
#  'Mdfi',
#  'Satb1',
#  'Ptprs',
#  'Lonp1',
#  'Mllt1',
#  'Tubb4a',
#  'Pja2',
#  'Twsg1',
#  'Ankrd12',
#  'Mtcl1',
#  'Tgif1',
#  'Memo1',
#  'Cdc42ep3',
#  'Lrpprc',
#  'Srbd1',
#  'Pigf',
#  'Mcfd2',
#  'Kcnk12',
#  'Zdhhc14',
#  'Snx9',
#  'Tulp4',
#  'Mpc1',
#  'Pde10a',
#  'Agpat4',
#  'Smoc2',
#  'Ppp2r1a',
#  'Cldn6',
#  'Msrb1',
#  'Hagh',
#  'Crebrf',
#  'Kifc5b',
#  'Pacsin1',
#  'Cdkn1a',
#  'Fgd2',
#  'Pim1',
#  'Abcg1',
#  'Slc37a1',
#  'Tapbp',
#  'Dxo',
#  'Clic1',
#  'Ddah2',
#  'H2-D1',
#  'Adgrf5',
#  'Gtpbp2',
#  'Xpo5',
#  'Tfeb',
#  'Kcnh8',
#  'Uhrf1',
#  'Ddx11',
#  'Ypel5',
#  'Yipf4',
#  'Birc6',
#  'Ttc27',
#  'Rasgrp3',
#  'Ndufaf7',
#  'Tmem178',
#  'Pkdcc',
#  'Plekhh2',
#  'Dync2li1',
#  'Rock1',
#  'Cdh2',
#  'B4galt6',
#  'Nol4',
#  'Celf4',
#  'Nrep',
#  'Reep5',
#  'Nme5',
#  'Gfra3',
#  'Ppp2r2b',
#  'Spink1',
#  'Sema6a',
#  'Ppic',
#  'Atp8b1',
#  'Slc14a2',
#  'Setbp1',
#  'Galr1',
#  'Tshz1',
#  'Bambi',
#  'Zeb1',
#  'Impact',
#  'Ttr',
#  'Polr2d',
#  'Wdr36',
#  'Kif20a',
#  'Egr1',
#  'Cystm1',
#  'Arhgap26',
#  'Stk32a',
#  'Hsd17b4',
#  'Dctn4',
#  'Nedd4l',
#  'Sec11c',
#  'Tubb6',
#  'Psmg2',
#  'Cep192',
#  'Dym',
#  'Zbtb7c',
#  'Atp5a1',
#  'Zfp516',
#  'Klc2',
#  'Snx32',
#  'Malat1',
#  'Snx15',
#  'Ppp2r5b',
#  'Gm14964',
#  'Fkbp2',
#  'Stip1',
#  'Flrt1',
#  'Cox8a',
#  'Rtn3',
#  'Polr2g',
#  'Incenp',
#  'Fads2',
#  'Fen1',
#  'Psat1',
#  'Cep78',
#  'Ostf1',
#  'Pip5k1b',
#  'Rfx3',
#  'Glis3',
#  'Ankrd1',
#  'Rbp4',
#  'Pdlim1',
#  'Blnk',
#  'Slit1',
#  'Cpn1',
#  'Npm3',
#  'Nt5c2',
#  'Sorcs1',
#  'Unc93b1',
#  'Ppp1ca',
#  'Ctsf',
#  'Efemp2',
#  'Cfl1',
#  'Rcor2',
#  'Syt7',
#  'Gnaq',
#  'Prune2',
#  'Vldlr',
#  'Ric1',
#  'A1cf',
#  'Papss2',
#  'Kif11',
#  'Hhex',
#  'Ffar4',
#  'Hells',
#  'Ankrd2',
#  'Zfyve27',
#  'Golga7b',
#  'Scd2',
#  'Pprc1',
#  'Fbxl15',
#  'Neurl1a',
#  'Ins1',
#  'Dusp5',
#  'Pdcd4',
#  'Tcf7l2',
#  'Habp2',
#  'Trub1',
#  'Pnliprp1',
#  'Celf2',
#  'Atp5c1',
#  'Rbm17',
#  'Mastl',
#  'BC029214',
#  'Ptgds',
#  'Rexo4',
#  'Gm13373',
#  '1700026L06Rik',
#  'Cfap77',
#  'Swi5',
#  'Dnm1',
#  'Stxbp1',
#  'Lmx1b',
#  'Rc3h2',
#  'Zeb2',
#  'Rnd3',
#  'Nr4a2',
#  'Cytip',
#  'Acvr1c',
#  'Baz2b',
#  'Dpp4',
#  'Gcg',
#  'Kcnh7',
#  'Scn3a',
#  'Scn9a',
#  'Spc25',
#  'Fkbp7',
#  'Cerkl',
#  'Neurod1',
#  'Pde1a',
#  'Frzb',
#  'Clp1',
#  'Serping1',
#  'Madd',
#  'Mdk',
#  'Creb3l1',
#  'Mapk8ip1',
#  'Cry2',
#  'Cd82',
#  'Api5',
#  'Ehf',
#  'Rcn1',
#  'Pax6os1',
#  'Scg5',
#  'Gjd2',
#  'Meis2',
#  'Ehd4',
#  'Epb42',
#  'Shf',
#  'Myef2',
#  'Hdc',
#  'Kcnip3',
#  'Ckap2l',
#  'Snrpb',
#  'Avp',
#  '4930402H24Rik',
#  'Pcna',
#  'Gpcpd1',
#  'Tmx4',
#  'Pcsk2os1',
#  'Rrbp1',
#  'Ovol2',
#  'Nkx2-2',
#  'Foxa2',
#  'Bcl2l1',
#  'Nol4l',
#  'E2f1',
#  'Pigu',
#  'Edem2',
#  'Eif6',
#  'Rbl1',
#  'Tgm2',
#  'Serinc3',
#  'Wfdc15b',
#  ...]

# %%
np.unique(anndata.X.toarray())
# Out:
# array([0.        , 0.28846455, 0.293713  , ..., 7.1136084 , 7.2068896 ,
#        7.306362  ], dtype=float32)

# %%
anndata.X[:,'Arl8a']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 anndata.X[:,'Arl8a']
#
# File /usr/bin/my_programs/miniconda3/envs/transformer/lib/python3.11/site-packages/scipy/sparse/_index.py:47, in IndexMixin.__getitem__(self, key)
#      46 def __getitem__(self, key):
# ---> 47     row, col = self._validate_indices(key)
#      49     # Dispatch to specialized methods.
#      50     if isinstance(row, INT_TYPES):
#
# File /usr/bin/my_programs/miniconda3/envs/transformer/lib/python3.11/site-packages/scipy/sparse/_index.py:168, in IndexMixin._validate_indices(self, key)
#     166         col += N
#     167 elif not isinstance(col, slice):
# --> 168     col = self._asindices(col, N)
#     170 return row, col
#
# File /usr/bin/my_programs/miniconda3/envs/transformer/lib/python3.11/site-packages/scipy/sparse/_index.py:183, in IndexMixin._asindices(self, idx, length)
#     180     raise IndexError('invalid index') from e
#     182 if x.ndim not in (1, 2):
# --> 183     raise IndexError('Index dimension must be 1 or 2')
#     185 if x.size == 0:
#     186     return x
#
# IndexError: Index dimension must be 1 or 2

# %%
anndata.var
# Out:
#         highly_variable_genes  gene_count_corr
# index
# Mrpl15                  False           0.0448
# Sntg1                    True          -0.0226
# Vcpip1                  False           0.0008
# Snhg6                   False          -0.0037
# Cops5                    True          -0.0346
# ...                       ...              ...
# Arhgap6                 False           0.0794
# Uty                     False          -0.0269
# Ddx3y                    True          -0.0484
# Eif2s3y                  True          -0.0601
# Erdr1                    True          -0.0065
#
# [8357 rows x 2 columns]
